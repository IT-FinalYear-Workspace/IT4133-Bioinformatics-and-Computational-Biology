# %% [markdown]
# # 09.18 Practical Pandas

# %%
import pandas as pd

# %% [markdown]
# ## Series

# %%
s1=pd.Series([1,2,3])
s1
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s2= pd.Series([1,2,3], index=['b','c','d'])
s2
# Out:
# b    1
# c    2
# d    3
# dtype: int64

# %% [markdown]
# ## DataFrame

# %% [markdown]
# ### Method 01

# %%
data= {'Name': ['Alice', 'Bob','Nimal'],'Age':[25,30,22]}
df=pd.DataFrame(data)
df
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30
# 2  Nimal   22
