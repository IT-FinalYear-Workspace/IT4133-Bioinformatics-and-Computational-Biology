# %%
print("Hello World")
# Out:
# Hello World

# %%
a=5
b='String'
print(a)
print(b)
print(type(a))
print(type(b))
# Out:
# 5
# String
# <class 'int'>
# <class 'str'>

# %%
num1=int(input("Enter the Number1: "))
num2=int(input("Enter the Number2: "))
# Out:
# Enter the Number1:  2
# Enter the Number2:  2

# %%
mul=num1*num2
sum=num1+num2

# %%
if mul > 1000:
    print(f"the output is , {sum} (because the mul is greater than 1000)")
else:
        print(f"the output is, {mul}")
# Out:
# the output is, 4

# %%
word="test"
vowel='aeiou'
vcount=0
for i in word:
    if i in vowel:
        vcount+=1
print(vcount)
# Out:
# 1

# %%
fruits = ["apple", "banana"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana

# %%
def get_min_max(numbers):
    return min(numbers), max(numbers)
minimum, maximum = get_min_max([1, 5, 3])
print(minimum,maximum)
# Out:
# 1 5

# %%
star=5
for i in range(1,star+1):
    print(i*'*')
# Out:
# *
# **
# ***
# ****
# *****

# %%
rows=10
for i in range(1, rows + 1):
    print(" " * (rows - i), end="")
    print("*" * (2 * i - 1))
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************

# %%
dnaType='ATGC'
DNA='ATGCGATACGCTTGA'
DnaCount=[0,0,0,0]

# for j in DNA:
#     if i in dnaType:
#         if i ='A':
#             DnaCount[0]+=1
#         if i='T':
#             DnaCount[1]+=1
#         if i='G':
#             DnaCount[2]+=1
#         if i='C':
#             DnaCount[3]+=1

#             print(DnaCount)

for i in DNA:
    if i in dnaType:
        index=dnaType.index(i)
        DnaCount[index]+=1
print(f"A:{DnaCount[0]}\nT:{DnaCount[1]}\nG:{DnaCount[2]}\nC:{DnaCount[3]}\n")
# Out:
# A:4
# T:4
# G:4
# C:3
